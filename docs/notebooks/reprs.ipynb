# %%
import dask

# %%
da = dask.array.empty(shape=(10000, 10000, 10000), chunks=(10, 10, 10))
da
# Out:
# dask.array<empty_like, shape=(10000, 10000, 10000), dtype=float64, chunksize=(10, 10, 10), chunktype=numpy.ndarray>
